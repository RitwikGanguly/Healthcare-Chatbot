# %%
import requests

def find_nearby_hospitals(latitude, longitude):
    # API endpoint
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # API parameters
    params = {
        "location": f"{latitude},{longitude}",
        "radius": 5000,  # Search radius in meters
        "type": "hospital",
        "key": "AIzaSyDSk0PNdaUakNl5slNMlkSO74H4qJ4KRvI"  # Replace with your actual API key
    }

    # Send a GET request to the API
    response = requests.get(url, params=params)
    data = response.json()
    print(data)
    # Check if the API request was successful
    if response.status_code == 200 and data["status"] == "OK":
        # Process the results
        hospitals = data["results"]
        for i, hospital in enumerate(hospitals[:5]):
            print(f"{i+1}. {hospital['name']}: {hospital['vicinity']}")
    else:
        print("Failed to retrieve nearby hospitals.")

# Example usage
latitude = 22.5754  # Example latitude
longitude = 88.4798  # Example longitude
find_nearby_hospitals(latitude, longitude)
# Out:
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'html_attributions': [], 'results': [], 'status': 'REQUEST_DENIED'}
# Failed to retrieve nearby hospitals.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome(executable_path=r'C:\Users\RITWIK GANGULY\anaconda3\chromedriver.exe')
driver.maximize_window()

# %%
import os
os.chdir(r"D:\Ritwik's Download\Healthcare Chatbot")

# %%
import pandas as pd
df = pd.read_csv("hospital_final.csv")
df.drop(["Latitude", "longitude"], axis=1, inplace=True)

# %%
df
# Out:
#      Hospital Code                           Name Of Hospital  \
# 0           411001           DESUN HOSPITAL & HEART INSTITUTE
# 1           411002    THE CALCUTTA MEDICAL RESEARCH INSTITUTE
# 2           411003          NIGHTINGALE DIAGNOSTIC & MEDICARE
# 3           411006                         MALDA NURSING HOME
# 4           411007           B.M. BIRLA HEART RESEARCH CENTRE
# ..             ...                                        ...
# 138         421010   DOYEN DIAGNOSTIC AND RESEARCH FOUNDATION
# 139         421011  THEISM ULTRASOUND CENTRE IMAGING DIVISION
# 140         421012                    FMC HEALTH CARE PVT LTD
# 141         421014                         FUTURE DIAGNOSTICS
# 142         421015       MEDINOVA DIAGNOSTIC SERVICES LIMITED
#
#                                    Address of Hospital  \
# 0    DESUN MORE ,KASBA GOL PARK,EM BYPASS, KOLKATA-...
# 1    7/2,DH RD,KOLKATA-\n700027, Mail ID-\ninfo@cmr...
# ...

# %%
add = df["current address"].tolist()

# %%
driver.get("https://www.latlong.net/")

# %%
l = []
m = []
c = 0

# %%
driver.find_element(By.XPATH, "//*[@id='address']").clear()
driver.find_element(By.XPATH, "//*[@id='latitude']").clear()
driver.find_element(By.XPATH, "//*[@id='longitude']").clear()

# %%
def get_lat_long(a):
#     driver.get("https://www.latlong.net/")
    try:
        driver.find_element(By.XPATH, "//*[@id='place']").clear()
        driver.find_element(By.XPATH, "//*[@id='place']").send_keys(a)
        driver.find_element(By.XPATH, "//*[@id='btnfind']").click()
        lat = driver.find_element(By.XPATH, "//*[@id='lat']").get_attribute("value")
        long = driver.find_element(By.XPATH, "//*[@id='lng']").get_attribute("value")
        l.append(lat)
        m.append(long)
        print(l)
        print(m)
    
    except:
        l.append("0.0000")
        m.append("0.0000")
        print("Error occures")

# %%
get_lat_long("219P,IMMON KALYAN SARANI, SECTOR 2C, BIDHAN NAGAR, DURGAPUR-713212")
# Out:
# ['0.000000']
# ['0.000000']

# %%
# lat = driver.find_element(By.XPATH, "//*[@id='latitude']").get_attribute("value")
# long = driver.find_element(By.XPATH, "//*[@id='longitude']").get_attribute("value")
# long

# %%
print(l)
print(m)
# Out:
# []
# []

# %%
add
# Out:
# ['DESUN MORE ,KASBA GOL PARK,EM BYPASS, KOLKATA-700107.',
#  '7/2,DH RD,KOLKATA- 700027',
#  '11, SHAKESPEARE SARANI, KOLKATA-700071',
#  'B.G. ROAD, MAKDUMPUR, MALDA',
#  '1/1, NATIONAL LIBRARY AVENUE, KOLKATA-700027',
#  '124,MUKUNDAPUR, EM BYPASS,KOLKATA-700099',
#  'MEGHNAD SAHA SARANI,PRADHAN NAGAR, SILIGURI-734003',
#  'KASBA GOL PARK, EM BYEPASS, KOLKATA- 700107',
#  '71/1 HUMAYUN KABIR SARANI, BLOCK-G, NEW ALIPORE,  KOLKATA- 700053',
#  'JUNCTION OF VIP ROAD &AMP NEW TOWN APPROACH ROAD, TEGHORIA,KOLKATA- 700059',
#  'ANDUL ROAD, P.O. PODRAH,HOWRAH-711109',
#  '111/1, JESSORE ROAD, BARASAT,KOLKATA- 700124',
#  'BONDANGA, PRANTIK, P.O.- SHANTINIKETAN',
#  '125/1,PARK STREET, KOLKATA-700017',
#  'CN-5, SECTOR-V, SALT LAKE, KOLKATA-700091',
#  '219P,IMMON KALYAN SARANI, SECTOR 2C, BIDHAN NAGAR, DURGAPUR-713212',
#  'BAMCHANDAIPUR, G.T. ROAD,BURDWAN-713101',
#  '105/1, R.S VERMA ROAD, UTTARPARA, HOOGHLY',
#  'A-9/16 S &AMP A-9/17 S, KALYANI, NADIA',
# ...

# %%
for i in range(50, len(add)):
    get_lat_long(add[i])
    
    print("pass complete - {}".format(i+1))
# Out:
# ['22.486420', '22.522830', '22.544580', '24.989281', '22.533291', '22.492230', '26.731420', '22.486420', '22.514320', '22.626440', '22.565060', '22.723260', '23.691150', '22.544100', '22.578100', '23.518540', '23.220120', '22.662540', '42.243630', '22.591770', '26.730920', '23.520890', '22.656050', '22.461130', '22.607390', '23.711210', '22.549440', '22.492230', '22.763590', '22.743139', '22.569510', '22.512840', '0.000000', '22.546530', '0.000000', '20.947310', '42.606241', '23.589460', '23.254080', '0.000000', '25.012410', '22.521920', '19.148230', '22.492850', '0.000000', '26.704510', '23.509060', '-34.610279', '38.807484', '22.477890', '22.731320']
# ...

# %%
df["latitude"] = l

# %%
df["longitude"] = m

# %%
df.loc[85]
# Out:
# Hospital Code                                                     412221
# Name Of Hospital                       DR. S. S. CHATTERJEE HEART CENTRE
# Address of Hospital    11/5, DR.BIRESH GUHA STREET, PARK CIRCUS, KOLK...
# current address        11/5, DR.BIRESH GUHA STREET, PARK CIRCUS, KOLK...
# Phone Number                                           033-\n22800281/03
# Class Recommended                              MULTI SPECIALITY HOSPITAL
# Notification Number                                          48-F(MED)WB
# Notification Date                                               9/7/2019
# Valid Upto                                                    31/03/2023
# latitude                                                       22.538660
# longitude                                                      88.371570
# Name: 85, dtype: object

# %%
# converting to float
df.latitude = df.latitude.astype("float")
df.longitude = df.longitude.astype("float")

# %%
df.dtypes
# Out:
# Hospital Code            int64
# Name Of Hospital        object
# Address of Hospital     object
# current address         object
# Phone Number            object
# Class Recommended       object
# Notification Number     object
# Notification Date       object
# Valid Upto              object
# latitude               float64
# longitude              float64
# dtype: object

# %% [markdown]
# ## Current Location

# %%
import folium

# %%
mymap = folium.Map(location=[23.2164, 88.3529], zoom_start=12)


folium.Marker(location=[23.2164, 88.3529], icon=folium.Icon(icon='medkit', prefix='fa', color='green'), popup='Your Location').add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df.latitude.max()
# Out:
# '26.760326'

# %%
df.latitude.min()
# Out:
# '21.7884623'

# %%
df.longitude.max()
# Out:
# '89.449870'

# %%
df.longitude.min()
# Out:
# '86.126'

# %%
import numpy as np

# %%
# make an 2D array of latitude & longitude 
arr = np.transpose(np.array([df.latitude, df.longitude]))
arr
# Out:
# array([[22.48642   , 88.393501  ],
#        [22.52283   , 88.32501   ],
#        [22.54458   , 88.35696   ],
#        [24.989281  , 88.146011  ],
#        [22.533291  , 88.327507  ],
#        [22.49223   , 88.39662   ],
#        [26.73142   , 88.41547   ],
#        [22.48642   , 88.3935    ],
#        [22.51432   , 88.32867   ],
#        [22.62644   , 88.43335   ],
#        [22.56506   , 88.28399   ],
#        [22.72326   , 88.49227   ],
#        [23.69115   , 87.68741   ],
#        [22.5441    , 88.36502   ],
#        [22.5781    , 88.42471   ],
#        [23.51854   , 87.35726   ],
#        [23.22012   , 87.88893   ],
#        [22.66254   , 88.34183   ],
#        [23.0056857 , 88.4690161 ],
#        [22.59177   , 88.42019   ],
#        [26.73092   , 88.43463   ],
#        [23.52089   , 87.33773   ],
#        [22.65605   , 88.46424   ],
#        [22.46113   , 88.30916   ],
#        [22.60739   , 88.38373   ],
#        [23.71121   , 86.95261   ],
#        [22.54944   , 88.36258   ],
# ...

# %%
df.columns
# Out:
# Index(['Hospital Code', 'Name Of Hospital', 'Address of Hospital',
#        'current address', 'Phone Number', 'Class Recommended',
#        'Notification Number', 'Notification Date', 'Valid Upto', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
data1["Distance"] = newdis

# %%
# Create a map object
m = folium.Map(location=[df.latitude.mean(), df.longitude.mean()], zoom_start=13)
folium.Marker(location=[data.latitude.mean(), data.longitude.mean()], icon = folium.Icon(icon='home', color='red', prefix="fa"), popup='Your Location', size = 155).add_to(m)


# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
    # Extract the hospital details from the row
    hospital_location = [row['latitude'], row['longitude']]
    hospital_name = row['Name Of Hospital']
    hospital_address = row['current address']
    hospital_phone = row['Phone Number']
    class_rec = row["Class Recommended"]
    
    # hovering to show the name of hospital
    
#     tooltip_text = f"{hospital_name}"
#     tooltip = folium.Tooltip(f"{hospital_name}")
    
    # Create a marker for the hospital
    popup_text = f"<b>{hospital_name}</b><br>{hospital_address}<br>Phone: {hospital_phone}<br>{class_rec}"
    folium.Marker(
        tooltip=str(df.iloc[index]['Name Of Hospital']),
        location=hospital_location,
        popup=popup_text,
        icon=folium.Icon(icon='medkit', prefix='fa', color='red')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df.iloc[9]["Name Of Hospital"]
# Out:
# 'CHARNOCK HOSPITALS PVT. LTD.'

# %% [markdown]
# ## Top 5 nearest Hospital

# %%
lat = float(input("Enter latitude: "))
long = float(input("Enter the Longitude: "))
ans = np.array((lat,long))
ans
# Out:
# Enter latitude: 22.5105
# Enter the Longitude: 88.4151
# array([22.5105, 88.4151])

# %% [markdown]
# ### Finding the Distance

# %%
dis = np.sqrt(np.sum((arr-ans)**2, axis=1))
dis = dis.tolist()
dis
# Out:
# [0.032347537788830934,
#  0.09092984658514522,
#  0.06739218055530868,
#  2.4933439666203268,
#  0.09050946541660493,
#  0.025986598469209466,
#  4.2209200162168425,
#  0.03234820551436719,
#  0.08651437626197614,
#  0.11736756834833016,
#  0.14200924512156904,
#  0.22632283689455912,
#  1.3868911848447207,
#  0.060307266560501664,
#  0.06827966095404993,
#  1.4612221279463296,
#  0.8834112367974467,
#  0.16877397459323795,
#  0.4981122597604895,
#  0.08142923922031994,
#  4.220465187310518,
#  1.4770287976204142,
#  0.15362142461258732,
#  0.11687891383820176,
#  0.10184178415561758,
#  1.8922424538626037,
#  0.06538099112127427,
#  0.025986598469209466,
#  0.257078704291117,
#  0.24280402731832817,
#  0.0701651031496423,
#  0.014154758917054219,
#  0.044795241934829644,
#  0.0681271847356042,
#  0.30127605887777853,
#  0.9310801684065664,
#  1.3577513104026062,
#  1.5774965361610063,
#  0.9306613411977473,
#  4.24982944217259,
#  2.515925154729367,
#  0.08371261135574755,
# ...

# %%
newdis = [round(i, 4) for i in dis]
newdis
# Out:
# [0.0323,
#  0.0909,
#  0.0674,
#  2.4933,
#  0.0905,
#  0.026,
#  4.2209,
#  0.0323,
#  0.0865,
#  0.1174,
#  0.142,
#  0.2263,
#  1.3869,
#  0.0603,
#  0.0683,
#  1.4612,
#  0.8834,
#  0.1688,
#  0.4981,
#  0.0814,
#  4.2205,
#  1.477,
#  0.1536,
#  0.1169,
#  0.1018,
#  1.8922,
#  0.0654,
#  0.026,
#  0.2571,
#  0.2428,
#  0.0702,
#  0.0142,
#  0.0448,
#  0.0681,
#  0.3013,
#  0.9311,
#  1.3578,
#  1.5775,
#  0.9307,
#  4.2498,
#  2.5159,
#  0.0837,
#  1.6555,
#  0.0468,
#  0.5815,
#  4.194,
#  1.4644,
#  0.1049,
#  0.021,
#  0.0425,
#  0.2378,
#  3.957,
#  0.4602,
#  0.0473,
#  0.2585,
#  1.5172,
#  0.1136,
#  0.142,
#  0.1204,
#  0.3161,
#  3.9515,
#  0.0992,
#  0.9076,
#  4.1823,
#  1.5217,
#  0.2369,
#  1.448,
#  0.4645,
#  4.2093,
#  2.3462,
#  0.1018,
#  0.0531,
#  0.0518,
#  0.2235,
#  1.5344,
#  1.6056,
#  0.0699,
#  0.3704,
#  0.0978,
#  1.5258,
#  1.5258,
#  0.1072,
#  2.5109,
#  0.1506,
#  4.2209,
#  0.0518,
#  0.103,
#  1.566,
#  0.2013,
#  1.5959,
#  4.2109,
# ...

# %%
megh1 = df.copy()

# %%
megh1["aliah_dis"] = newdis

# %%
top_5_hos = megh1.sort_values(by='aliah_dis').head(10)
top_5_hos
# Out:
#      Hospital Code                                   Name Of Hospital  \
# 114         413410          R.G. STONE UROLOGY & LAPAROSCOPY HOSPITAL
# 31          411040                           FORTIS HOSPITALS LIMITED
# 141         421014                                 FUTURE DIAGNOSTICS
# 48          411060                          AMRI HOSPITALS MUKUNDAPUR
# 5           411008  R N TAGORE INTERNATIONAL INSTITUTE OF CARDIAC ...
# 27          411034                    MEDICA SUPERSPECIALITY HOSPITAL
# 106         412243         OHIO CARDIOLOGY ASSOCIATES INDIA PVT. LTD.
# 0           411001                   DESUN HOSPITAL & HEART INSTITUTE
# 7           411011                              RUBY GENERAL HOSPITAL
# 49          411061                                      IRIS HOSPITAL
#
#                                    Address of Hospital  \
# 114                33, GARIAHAT ROAD SOUTH, KOLKATA-31
# 31   730,ANANDAPUR, KOLKATA-700107, Mail ID-\nipbil...
# ...

# %% [markdown]
# ### MapView - Aliah

# %%
# Create a map object
m = folium.Map(location=[lat, long], zoom_start=13)
folium.Marker(location=[lat, long], icon = folium.Icon(icon='home', color='red', prefix="fa"), popup='Your Location', size = 155).add_to(m)


# Iterate over the rows of the DataFrame
for index, row in top_5_hos.iterrows():
    # Extract the hospital details from the row
    hospital_location = [row['latitude'], row['longitude']]
    hospital_name = row['Name Of Hospital']
    hospital_address = row['current address']
    hospital_phone = row['Phone Number']
    class_rec = row["Class Recommended"]
    
    # hovering to show the name of hospital
    
#     tooltip_text = f"{hospital_name}"
#     tooltip = folium.Tooltip(f"{hospital_name}")
    
    # Create a marker for the hospital
    popup_text = f"<b>{hospital_name}</b><br>{hospital_address}<br>Phone: {hospital_phone}<br>{class_rec}"
    folium.Marker(
        tooltip=str(df.iloc[index]['Name Of Hospital']),
        location=hospital_location,
        popup=popup_text,
        icon=folium.Icon(icon='medkit', prefix='fa', color='red')
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
megh1.loc[7]
# Out:
# Hospital Code                                                     411011
# Name Of Hospital                                   RUBY GENERAL HOSPITAL
# Address of Hospital    KASBA GOL PARK, EM BYEPASS, KOLKATA- 700107, M...
# current address              KASBA GOL PARK, EM BYEPASS, KOLKATA- 700107
# Phone Number                                                  3339871800
# Class Recommended                              MULTI SPECIALITY HOSPITAL
# Notification Number                                          94-F(MED)WB
# Notification Date                                             13/11/2019
# Valid Upto                                                    31/03/2023
# latitude                                                         22.5135
# longitude                                                        88.4029
# aliah_dis                                                         0.0323
# Name: 7, dtype: object

# %%
df.at[0, 'latitude'] = 22.5146
df.at[0, "longitude"] = 88.4032
